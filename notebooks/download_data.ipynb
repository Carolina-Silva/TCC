# %% [markdown]
# # Downloading data from DATASUS

# %%
# Installing the library we used to download the data from DATASUS
# %pip install pandas pysus
# Out:
# ...
# WARNING: elasticsearch 7.16.2 does not provide the extra 'preprocessing'
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# Databases that will be used
from pysus.online_data import SIM, SIH, CNES

# python libraries
import os

# %% [markdown]
# ## DOWNLOAD

# %%
data_SIM = SIM.download(groups=["cid10"],states='SP', years=2022)
data_SIM
# Out:
# 28630082it [00:00, 63976168062.30it/s]
# /home/carolina/pysus/DOSP2022.parquet

# %%
data_SIH = SIH.download(groups="SP", states="SP",  months=[1], years=2022 )
data_SIH
# Out:
# 61784247it [00:00, 49729785900.80it/s]
# /home/carolina/pysus/SPSP2201.parquet

# %%
data_CNES = CNES.download(group='LT', states='SP', years=2023, months=1)
data_CNES
# Out:
# 99462it [00:00, 396553103.09it/s]
# /home/carolina/pysus/LTSP2301.parquet

# %% [markdown]
# ## MAKE DFs

# %%
df_SIM = data_SIM.to_dataframe()
print(df_SIM.shape)
df_SIM.head()
# Out:
# (354056, 87)
#   ORIGEM TIPOBITO   DTOBITO HORAOBITO NATURAL CODMUNNATU    DTNASC IDADE  \
# 0      1        2  26122022               835    355030   05041977   445
# 1      1        2  26122022     1652      835    355030   22021976   446
# 2      1        2  26122022     1557      835    355030   19101980   442
# 3      1        2  15112022     0845      835    355030   23091960   462
# 4      1        2  27122022     0948      835    355030   28041985   437
#
#    SEXO RACACOR  ... FONTES TPRESGINFO TPNIVELINV NUDIASINF DTCADINF  \
# 0     2       1  ...                            M
# 1     2       1  ...                            M
# 2     2       4  ...                            M
# 3     2       1  ...
# 4     2       3  ...                            M
#
#    MORTEPARTO DTCONCASO FONTESINF ALTCAUSA  CONTADOR
# 0                                           1045502
# 1                                           1045503
# 2                                           1045504
# ...

# %%
df_SIH = data_SIH.to_dataframe()
print(df_SIH.shape)
df_SIH.head()
# Out:
# (3407996, 36)
#   SP_GESTOR SP_UF SP_AA SP_MM  SP_CNES        SP_NAIH  SP_PROCREA SP_DTINTER  \
# 0    350950    35  2022    01  6053858  3522105835260  0303060140   20211113
# 1    350950    35  2022    01  6053858  3522105835260  0303060140   20211113
# 2    350950    35  2022    01  6053858  3522105835260  0303060140   20211113
# 3    350950    35  2022    01  6053858  3522105835260  0303060140   20211113
# 4    350950    35  2022    01  6053858  3522105835260  0303060140   20211113
#
#   SP_DTSAIDA SP_NUM_PR  ...        SP_PF_DOC       SP_PJ_DOC IN_TP_VAL  \
# 0   20220118            ...  980016277727031  00000006053858         1
# 1   20220118            ...  980016277727031  00000006053858         1
# 2   20220118            ...  980016277727031  00000006053858         1
# 3   20220118            ...  708602091447387  00000006053858         1
# 4   20220118            ...  708602091447387  00000006053858         1
#
# ...

# %%
df_CNES = data_CNES.to_dataframe()
print(df_CNES.shape)
df_CNES.head()
# Out:
# (8308, 28)
#       CNES CODUFMUN REGSAUDE MICR_REG DISTRSAN DISTRADM TPGESTAO PF_PJ  \
# 0  2077647   350010     0209                                   M     3
# 1  2077647   350010     0209                                   M     3
# 2  2077647   350010     0209                                   M     3
# 3  2077647   350010     0209                                   M     3
# 4  2077647   350010     0209                                   M     3
#
#          CPF_CNPJ NIV_DEP  ... NIV_HIER TERCEIRO TP_LEITO CODLEITO QT_EXIST  \
# 0  53221255006777       1  ...                         2        33       63
# 1  53221255006777       1  ...                         5        68        1
# 2  53221255006777       1  ...                         4        10        9
# 3  53221255006777       1  ...                         2        31        2
# 4  53221255006777       1  ...                         4        43        8
#
#   QT_CONTR QT_SUS QT_NSUS COMPETEN NAT_JUR
# ...

# %% [markdown]
# ## CLEAN

# %%
df_SIH
# Out:
#         SP_GESTOR SP_UF SP_AA SP_MM  SP_CNES        SP_NAIH  SP_PROCREA  \
# 0          350950    35  2022    01  6053858  3522105835260  0303060140
# 1          350950    35  2022    01  6053858  3522105835260  0303060140
# 2          350950    35  2022    01  6053858  3522105835260  0303060140
# 3          350950    35  2022    01  6053858  3522105835260  0303060140
# 4          350950    35  2022    01  6053858  3522105835260  0303060140
# ...           ...   ...   ...   ...      ...            ...         ...
# 3407991    353740    35  2022    01  2083027  3522106929902  0408050918
# 3407992    353740    35  2022    01  2083027  3522106929913  0408050462
# 3407993    353740    35  2022    01  2083027  3522106929913  0408050462
# 3407994    353740    35  2022    01  2083027  3522106929913  0408050462
# 3407995    353740    35  2022    01  2083027  3522106929913  0408050462
#
#         SP_DTINTER SP_DTSAIDA SP_NUM_PR  ...        SP_PF_DOC       SP_PJ_DOC  \
# ...
